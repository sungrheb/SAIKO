# %%
# 프로젝트 명 : 다음 증권 사이트에서 주식 정보를 크롤링 해서 데이터 분석을 위한 기본 단계를 진행해보기
# 프로젝트 설명 : 이번 프로젝트는 1~4 단계에서 배운 내용을 토대로 데이터를 수집하고 기본 분석을 수행하는 것이 목표입니다.
# 다음 증권 사이트에서 데이터를 수집한 뒤 판다스 데이터 프레임 형태로 변환하고 describe 등의 함수를 이용해서 간단하게 분석을 수행해 봅시다.

# 과제 상세 단계 
# 1. 특정 사이트에서 필요한 데이터 크롤링하기
# 2. 데이터를 판다스 데이터 프레임으로 변환하기
# 3. 기본 분석 수행하기 (describe, info 등)

# %% [markdown]
# # 데이터 수집해보기

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-12%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.48.16.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-12%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.48.16.png)

# %%
# 브라우저를 사용해서 대상 사이트를 확인하고 데이터 수집 대상 사이트 선정
# lg 전자 주가 데이터 페이지
# https://finance.daum.net/quotes/A066570#current/quote
# 대상 사이트 주소를 url 변수로 저장
url = ""

# %%
# 해당 주소에서 데이터 얻어오기
import requests

# %%
# 해당 url에 requests로 서버에서 접속해서 데이터 받아오기
req = requests.get(?)

# %%
# 데이터를 잘 받아왔는지 확인하기
if req.status_code == requests.codes.ok:
    print("접속 성공")
else:
    print("접속 실패")
# Out:
# 접속 성공

# %%
# 데이터 확인하기
print(?)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-12%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.48.22.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-12%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.48.22.png)

# %%
# 원하는 데이터를 찾아내자
# 데이터를 html로 변환
from bs4 import BeautifulSoup

# %%
# text 를 html 데이터로 변환
html = BeautifulSoup(?, "html.parser")

# %%
# 일자별 데이터 뽑아내기
data = html.select()

# %%
print(data)

# %% [markdown]
# ### 데이터 뽑기에 성공하셨나요?!

# %% [markdown]
# ## 데이터 뽑기에 실패했다면 방법을 바꿉시다.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-12%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.53.40.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-03-12%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.53.40.png)

# %%
# 네트워트 탭을 켜고 일자별 주가의 다른 페이지를 눌러봅시다.
# 나오는 네트워크 정보의 주소를 복사해와서 데이터를 수집해봅시다.
# https://finance.daum.net/api/quote/A066570/days?symbolCode=A066570&page=3&perPage=10&pagination=true

# %%
# 찾아낸 주소를 url 변수에 저장
url = "?"

# %%
# 다시 한번 requests로 데이터 수집

# %%
custom_headers = {
    "user-agent":"Mizilia",
    "referer":"https://www.daum.net"
}
req = requests.get(?, headers=custom_headers)

# %%
if req.status_code == requests.codes.ok:
    print("접속 성공")
else:
    print("접속 실패")
# Out:
# 접속 성공

# %%
# 데이터를 json 형식으로 변환
import json
json_data = json.loads(?)

# %%
# openpyxl 이 없다면
# !pip install openpyxl

# %%
from openpyxl import Workbook

# %%
# 한줄씩 엑셀에 데이터를 저장해보세요.
wb = Workbook() # 워크북 생성
ws = wb.active # 워크시트 생성
# 헤더열 생성
ws.append(["data", "openingPrice","highPrice", "lowPrice", "tradePrice"])

# 데이터 확인하기
for row in json_data['data']:
    print(row)
    
# 데이터 실제로 저장하기
for row in json_data['data']:'
    # data, openingPrice, highPrice, lowPrice, tradePrice 데이터를 저장하기
    ws.append([row['?'], row['?'],row['?'], row['?'],row['?']])
# Out:
# 2021-02-08 15:30:27 158000.0 163500.0 157000.0 157000.0
# 2021-02-05 15:30:26 159000.0 160500.0 154500.0 158000.0
# 2021-02-04 15:30:24 163000.0 163000.0 156000.0 157500.0
# 2021-02-03 15:30:07 160500.0 166000.0 159000.0 165000.0
# 2021-02-02 15:30:18 160000.0 164000.0 156000.0 158000.0
# 2021-02-01 15:30:27 153500.0 159000.0 150000.0 158000.0
# 2021-01-29 15:30:03 166500.0 166500.0 150500.0 153000.0
# 2021-01-28 15:30:04 163500.0 167000.0 161500.0 164500.0
# 2021-01-27 15:30:10 170000.0 175500.0 166500.0 167000.0
# 2021-01-26 15:30:29 179000.0 181500.0 169000.0 170000.0

# %%
# 엑셀 파일로 저장하기
wb.save("저장하고싶은 파일명")

# %%
# json 데이터를 판다스 dataframe으로 변환

# %%
import pandas as pd

# %%
# 방금 저장한 엑셀 파일을 df로 변환하세요.
df = pd.read_excel()

# %%
# 데이터를 확인해보세요.
# head, tail 등을
df.?()
# Out:
#                   data  openingPrice  highPrice  lowPrice  tradePrice
# 0  2021-02-08 15:30:27        158000     163500    157000      157000
# 1  2021-02-05 15:30:26        159000     160500    154500      158000
# 2  2021-02-04 15:30:24        163000     163000    156000      157500
# 3  2021-02-03 15:30:07        160500     166000    159000      165000
# 4  2021-02-02 15:30:18        160000     164000    156000      158000

# %%
# 데이터 구조와 타입 확인
df.?()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data          10 non-null     object
#  1   openingPrice  10 non-null     int64
#  2   highPrice     10 non-null     int64
#  3   lowPrice      10 non-null     int64
#  4   tradePrice    10 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 528.0+ bytes

# %%
# 수치 데이터 요약해보기.
df.?()
# Out:
#         openingPrice      highPrice       lowPrice     tradePrice
# count      10.000000      10.000000      10.000000      10.000000
# mean   163300.000000  166650.000000  158000.000000  160800.000000
# std      7173.252788    6880.124353    6218.252702    5417.051268
# min    153500.000000  159000.000000  150000.000000  153000.000000
# 25%    159250.000000  163125.000000  154875.000000  157625.000000
# 50%    161750.000000  165000.000000  156500.000000  158000.000000
# 75%    165750.000000  166875.000000  160875.000000  164875.000000
# max    179000.000000  181500.000000  169000.000000  170000.000000
